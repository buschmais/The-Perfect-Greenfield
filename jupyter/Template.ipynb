# %%
# %load_ext cypher
# %config CypherMagic.uri='http://neo4j:neo@localhost:7474/db/data'

# %% [markdown]
# # Topic

# %% [markdown]
# ## Question

# %% [markdown]
# <center>What do I want to find out?</center>

# %% [markdown]
# ## Data Sources

# %% [markdown]
# ## Heuristics

# %% [markdown]
# ## Validation

# %% [markdown]
# ## Implementation

# %% [markdown]
# ## Results

# %% [markdown]
# ## Next Steps
